# %%
import numpy as np
import matplotlib.pyplot as plt

inceotionV1 = pd.read_csv("inceptionV1_accuracy.csv", sep=',') 
inceotionV1=inceotionV1.to_numpy()
inceotionV1=inceotionV1.tolist()

vgg19 = pd.read_csv("VGG19_accuracy.csv", sep=',') 
vgg19=vgg19.to_numpy()
vgg19=vgg19.tolist()


MobileNet = pd.read_csv("MobileNet_accuracy.csv", sep=',') 
MobileNet=MobileNet.to_numpy()
MobileNet=MobileNet.tolist()

# %%
bodyPart = ['ELBOW', 'FINGER','FOREARM','HAND', 'HUMERUS', 'SHOULDER', 'WRIST']

plt.figure()
i=plt.scatter(inceotionV1,bodyPart,c='blue')
v=plt.scatter(vgg19,bodyPart,c='red')
m=plt.scatter(MobileNet,bodyPart,c='green')
plt.xlabel('Body Part')
plt.ylabel('Accuracy ')
plt.legend((i,v,m),
           ('inception','vgg19','MobileNet'),
           scatterpoints=1,
           loc='upper left',
           ncol=3,
           fontsize=8)
plt.show()
